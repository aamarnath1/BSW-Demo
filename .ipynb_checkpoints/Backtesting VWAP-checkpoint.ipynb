# %%
# !pip install nest_asyncio
# Out:
# Requirement already satisfied: nest_asyncio in d:\conda\envs\gpu_test2\lib\site-packages (1.6.0)

# %%
import backtrader as bt
import pandas as pd
import itertools

# %%
import nest_asyncio
import asyncio
import datetime
from alpaca.data.live import StockDataStream
from alpaca.data.historical import StockHistoricalDataClient
from alpaca.data.requests import StockBarsRequest
from alpaca.data.timeframe import TimeFrame

# Fix nested event loop error in Jupyter
nest_asyncio.apply()

# Your API keys
API_KEY = 'PKG6TZDDE9S53MEGFS9M'
SECRET_KEY = 's40b7OoDgOITfHXt9pL8TyHfo1xlcbEcFpXSfadx'

# --- HISTORICAL DATA ---
client = StockHistoricalDataClient(API_KEY, SECRET_KEY)

request_params = StockBarsRequest(
    symbol_or_symbols=["AAPL"],
    timeframe=TimeFrame.Minute,
    start=datetime.datetime.now() - datetime.timedelta(hours=1),
    end=datetime.datetime.now(),
)

bars = client.get_stock_bars(request_params)
print("Historical bars:")
print(bars)

# --- REAL-TIME STREAMING ---
# Create the data stream client
stream = StockDataStream(API_KEY, SECRET_KEY)

# Define the trade callback
async def on_trade(data):
    print(f"Trade: {data.symbol} | Price: {data.price} | Size: {data.size} | Timestamp: {data.timestamp}")

# Subscribe to real-time trades for AAPL
stream.subscribe_trades(on_trade, "AAPL")

# Start the stream using await (in Jupyter/IPython)
await stream.run()
# Out:
# Historical bars:
# data={'AAPL': [{   'close': 210.8402,
#     'high': 210.87,
#     'low': 210.7201,
#     'open': 210.81,
#     'symbol': 'AAPL',
#     'timestamp': datetime.datetime(2025, 5, 15, 18, 12, tzinfo=TzInfo(UTC)),
#     'trade_count': 869.0,
#     'volume': 50647.0,
#     'vwap': 210.811727}, {   'close': 210.89,
#     'high': 210.91,
#     'low': 210.84,
#     'open': 210.86,
#     'symbol': 'AAPL',
#     'timestamp': datetime.datetime(2025, 5, 15, 18, 13, tzinfo=TzInfo(UTC)),
#     'trade_count': 994.0,
#     'volume': 57968.0,
#     'vwap': 210.87545}, {   'close': 210.83,
#     'high': 210.87,
#     'low': 210.68,
#     'open': 210.87,
#     'symbol': 'AAPL',
#     'timestamp': datetime.datetime(2025, 5, 15, 18, 14, tzinfo=TzInfo(UTC)),
#     'trade_count': 1039.0,
#     'volume': 53226.0,
#     'vwap': 210.798301}, {   'close': 210.8299,
#     'high': 210.83,
#     'low': 210.68,
#     'open': 210.8264,
#     'symbol': 'AAPL',
#     'timestamp': datetime.datetime(2025, 5, 15, 18, 15, tzinfo=TzInfo(UTC)),
#     'trade_count': 849.0,
#     'volume': 42146.0,
#     'vwap': 210.761064}, {   'close': 210.7001,
#     'high': 210.9,
#     'low': 210.68,
#     'open': 210.82,
#     'symbol': 'AAPL',
#     'timestamp': datetime.datetime(2025, 5, 15, 18, 16, tzinfo=TzInfo(UTC)),
#     'trade_count': 904.0,
#     'volume': 46069.0,
#     'vwap': 210.798996}, {   'close': 210.72,
#     'high': 210.72,
#     'low': 210.5752,
#     'open': 210.69,
#     'symbol': 'AAPL',
#     'timestamp': datetime.datetime(2025, 5, 15, 18, 17, tzinfo=TzInfo(UTC)),
#     'trade_count': 1113.0,
#     'volume': 66032.0,
#     'vwap': 210.659978}, {   'close': 210.6504,
#     'high': 210.76,
#     'low': 210.59,
#     'open': 210.7,
#     'symbol': 'AAPL',
#     'timestamp': datetime.datetime(2025, 5, 15, 18, 18, tzinfo=TzInfo(UTC)),
#     'trade_count': 1026.0,
#     'volume': 57036.0,
#     'vwap': 210.679251}, {   'close': 210.47,
#     'high': 210.68,
#     'low': 210.47,
#     'open': 210.64,
#     'symbol': 'AAPL',
#     'timestamp': datetime.datetime(2025, 5, 15, 18, 19, tzinfo=TzInfo(UTC)),
#     'trade_count': 1211.0,
#     'volume': 76758.0,
#     'vwap': 210.540789}, {   'close': 210.3932,
#     'high': 210.51,
#     'low': 210.3532,
#     'open': 210.48,
#     'symbol': 'AAPL',
#     'timestamp': datetime.datetime(2025, 5, 15, 18, 20, tzinfo=TzInfo(UTC)),
#     'trade_count': 1044.0,
#     'volume': 61144.0,
#     'vwap': 210.441363}, {   'close': 210.44,
#     'high': 210.49,
#     'low': 210.25,
#     'open': 210.38,
#     'symbol': 'AAPL',
#     'timestamp': datetime.datetime(2025, 5, 15, 18, 21, tzinfo=TzInfo(UTC)),
#     'trade_count': 1603.0,
#     'volume': 116330.0,
#     'vwap': 210.396154}, {   'close': 210.42,
#     'high': 210.48,
#     'low': 210.32,
#     'open': 210.44,
#     'symbol': 'AAPL',
#     'timestamp': datetime.datetime(2025, 5, 15, 18, 22, tzinfo=TzInfo(UTC)),
#     'trade_count': 1035.0,
#     'volume': 73682.0,
#     'vwap': 210.415014}, {   'close': 210.5088,
#     'high': 210.52,
#     'low': 210.32,
#     'open': 210.42,
#     'symbol': 'AAPL',
#     'timestamp': datetime.datetime(2025, 5, 15, 18, 23, tzinfo=TzInfo(UTC)),
#     'trade_count': 1175.0,
#     'volume': 82272.0,
#     'vwap': 210.444124}, {   'close': 210.37,
#     'high': 210.5048,
#     'low': 210.27,
#     'open': 210.5,
#     'symbol': 'AAPL',
#     'timestamp': datetime.datetime(2025, 5, 15, 18, 24, tzinfo=TzInfo(UTC)),
#     'trade_count': 1693.0,
#     'volume': 126335.0,
#     'vwap': 210.366121}, {   'close': 210.43,
#     'high': 210.43,
#     'low': 210.31,
#     'open': 210.36,
#     'symbol': 'AAPL',
#     'timestamp': datetime.datetime(2025, 5, 15, 18, 25, tzinfo=TzInfo(UTC)),
#     'trade_count': 1042.0,
#     'volume': 84883.0,
#     'vwap': 210.360001}, {   'close': 210.63,
#     'high': 210.65,
#     'low': 210.4193,
#     'open': 210.43,
#     'symbol': 'AAPL',
#     'timestamp': datetime.datetime(2025, 5, 15, 18, 26, tzinfo=TzInfo(UTC)),
#     'trade_count': 1114.0,
#     'volume': 92528.0,
#     'vwap': 210.521946}, {   'close': 210.64,
#     'high': 210.68,
#     'low': 210.56,
#     'open': 210.63,
#     'symbol': 'AAPL',
#     'timestamp': datetime.datetime(2025, 5, 15, 18, 27, tzinfo=TzInfo(UTC)),
#     'trade_count': 1260.0,
#     'volume': 103949.0,
#     'vwap': 210.621194}, {   'close': 210.47,
#     'high': 210.679,
#     'low': 210.46,
#     'open': 210.65,
#     'symbol': 'AAPL',
#     'timestamp': datetime.datetime(2025, 5, 15, 18, 28, tzinfo=TzInfo(UTC)),
#     'trade_count': 1151.0,
#     'volume': 82954.0,
#     'vwap': 210.569177}, {   'close': 210.63,
#     'high': 210.63,
#     'low': 210.44,
#     'open': 210.47,
#     'symbol': 'AAPL',
#     'timestamp': datetime.datetime(2025, 5, 15, 18, 29, tzinfo=TzInfo(UTC)),
#     'trade_count': 868.0,
#     'volume': 65396.0,
#     'vwap': 210.542011}, {   'close': 210.9,
#     'high': 210.92,
#     'low': 210.62,
#     'open': 210.63,
#     'symbol': 'AAPL',
#     'timestamp': datetime.datetime(2025, 5, 15, 18, 30, tzinfo=TzInfo(UTC)),
#     'trade_count': 1242.0,
#     'volume': 79951.0,
#     'vwap': 210.813488}, {   'close': 210.97,
#     'high': 211.01,
#     'low': 210.835,
#     'open': 210.9,
#     'symbol': 'AAPL',
#     'timestamp': datetime.datetime(2025, 5, 15, 18, 31, tzinfo=TzInfo(UTC)),
#     'trade_count': 1056.0,
#     'volume': 77869.0,
#     'vwap': 210.925114}, {   'close': 210.98,
#     'high': 211.07,
#     'low': 210.92,
#     'open': 210.97,
#     'symbol': 'AAPL',
#     'timestamp': datetime.datetime(2025, 5, 15, 18, 32, tzinfo=TzInfo(UTC)),
#     'trade_count': 912.0,
#     'volume': 66783.0,
#     'vwap': 210.984538}, {   'close': 210.9,
#     'high': 211.03,
#     'low': 210.83,
#     'open': 210.98,
#     'symbol': 'AAPL',
#     'timestamp': datetime.datetime(2025, 5, 15, 18, 33, tzinfo=TzInfo(UTC)),
#     'trade_count': 897.0,
#     'volume': 66700.0,
#     'vwap': 210.929893}, {   'close': 210.985,
#     'high': 211.025,
#     'low': 210.9,
#     'open': 210.91,
#     'symbol': 'AAPL',
#     'timestamp': datetime.datetime(2025, 5, 15, 18, 34, tzinfo=TzInfo(UTC)),
#     'trade_count': 787.0,
#     'volume': 42866.0,
#     'vwap': 210.981334}, {   'close': 211.08,
#     'high': 211.09,
#     'low': 210.94,
#     'open': 210.97,
#     'symbol': 'AAPL',
#     'timestamp': datetime.datetime(2025, 5, 15, 18, 35, tzinfo=TzInfo(UTC)),
#     'trade_count': 915.0,
#     'volume': 57779.0,
#     'vwap': 211.041665}, {   'close': 211.07,
#     'high': 211.14,
#     'low': 211.04,
#     'open': 211.07,
#     'symbol': 'AAPL',
#     'timestamp': datetime.datetime(2025, 5, 15, 18, 36, tzinfo=TzInfo(UTC)),
#     'trade_count': 821.0,
#     'volume': 51792.0,
#     'vwap': 211.098753}, {   'close': 211.01,
#     'high': 211.08,
#     'low': 210.97,
#     'open': 211.08,
#     'symbol': 'AAPL',
#     'timestamp': datetime.datetime(2025, 5, 15, 18, 37, tzinfo=TzInfo(UTC)),
#     'trade_count': 806.0,
#     'volume': 45270.0,
#     'vwap': 211.010748}, {   'close': 211.03,
#     'high': 211.045,
#     'low': 210.94,
#     'open': 211.01,
#     'symbol': 'AAPL',
#     'timestamp': datetime.datetime(2025, 5, 15, 18, 38, tzinfo=TzInfo(UTC)),
#     'trade_count': 810.0,
#     'volume': 49096.0,
#     'vwap': 210.986624}, {   'close': 211.15,
#     'high': 211.17,
#     'low': 210.98,
#     'open': 211.03,
#     'symbol': 'AAPL',
#     'timestamp': datetime.datetime(2025, 5, 15, 18, 39, tzinfo=TzInfo(UTC)),
#     'trade_count': 1112.0,
#     'volume': 62874.0,
#     'vwap': 211.099477}, {   'close': 211.11,
#     'high': 211.16,
#     'low': 211.0101,
#     'open': 211.14,
#     'symbol': 'AAPL',
#     'timestamp': datetime.datetime(2025, 5, 15, 18, 40, tzinfo=TzInfo(UTC)),
#     'trade_count': 1325.0,
#     'volume': 98020.0,
#     'vwap': 211.099498}, {   'close': 211.15,
#     'high': 211.21,
#     'low': 211.09,
#     'open': 211.1,
#     'symbol': 'AAPL',
#     'timestamp': datetime.datetime(2025, 5, 15, 18, 41, tzinfo=TzInfo(UTC)),
#     'trade_count': 749.0,
#     'volume': 46353.0,
#     'vwap': 211.147735}, {   'close': 211.115,
#     'high': 211.145,
#     'low': 211.0,
#     'open': 211.14,
#     'symbol': 'AAPL',
#     'timestamp': datetime.datetime(2025, 5, 15, 18, 42, tzinfo=TzInfo(UTC)),
#     'trade_count': 748.0,
#     'volume': 41792.0,
#     'vwap': 211.07414}, {   'close': 211.08,
#     'high': 211.11,
#     'low': 211.03,
#     'open': 211.11,
#     'symbol': 'AAPL',
#     'timestamp': datetime.datetime(2025, 5, 15, 18, 43, tzinfo=TzInfo(UTC)),
#     'trade_count': 640.0,
#     'volume': 39136.0,
#     'vwap': 211.062251}, {   'close': 211.08,
#     'high': 211.15,
#     'low': 211.01,
#     'open': 211.07,
#     'symbol': 'AAPL',
#     'timestamp': datetime.datetime(2025, 5, 15, 18, 44, tzinfo=TzInfo(UTC)),
#     'trade_count': 750.0,
#     'volume': 45304.0,
#     'vwap': 211.054731}, {   'close': 210.8862,
#     'high': 211.09,
#     'low': 210.87,
#     'open': 211.06,
#     'symbol': 'AAPL',
#     'timestamp': datetime.datetime(2025, 5, 15, 18, 45, tzinfo=TzInfo(UTC)),
#     'trade_count': 965.0,
#     'volume': 60350.0,
#     'vwap': 210.954053}, {   'close': 210.88,
#     'high': 210.93,
#     'low': 210.81,
#     'open': 210.8703,
#     'symbol': 'AAPL',
#     'timestamp': datetime.datetime(2025, 5, 15, 18, 46, tzinfo=TzInfo(UTC)),
#     'trade_count': 898.0,
#     'volume': 56287.0,
#     'vwap': 210.85994}, {   'close': 210.79,
#     'high': 210.9,
#     'low': 210.77,
#     'open': 210.87,
#     'symbol': 'AAPL',
#     'timestamp': datetime.datetime(2025, 5, 15, 18, 47, tzinfo=TzInfo(UTC)),
#     'trade_count': 886.0,
#     'volume': 53879.0,
#     'vwap': 210.839379}, {   'close': 210.71,
#     'high': 210.8,
#     'low': 210.67,
#     'open': 210.78,
#     'symbol': 'AAPL',
#     'timestamp': datetime.datetime(2025, 5, 15, 18, 48, tzinfo=TzInfo(UTC)),
#     'trade_count': 915.0,
#     'volume': 51764.0,
#     'vwap': 210.735841}, {   'close': 210.7577,
#     'high': 210.7998,
#     'low': 210.63,
#     'open': 210.7,
#     'symbol': 'AAPL',
#     'timestamp': datetime.datetime(2025, 5, 15, 18, 49, tzinfo=TzInfo(UTC)),
#     'trade_count': 880.0,
#     'volume': 57921.0,
#     'vwap': 210.73025}, {   'close': 210.75,
#     'high': 210.78,
#     'low': 210.64,
#     'open': 210.74,
#     'symbol': 'AAPL',
#     'timestamp': datetime.datetime(2025, 5, 15, 18, 50, tzinfo=TzInfo(UTC)),
#     'trade_count': 783.0,
#     'volume': 43807.0,
#     'vwap': 210.706785}, {   'close': 210.635,
#     'high': 210.74,
#     'low': 210.615,
#     'open': 210.74,
#     'symbol': 'AAPL',
#     'timestamp': datetime.datetime(2025, 5, 15, 18, 51, tzinfo=TzInfo(UTC)),
#     'trade_count': 785.0,
#     'volume': 41538.0,
#     'vwap': 210.685265}, {   'close': 210.6687,
#     'high': 210.7,
#     'low': 210.6,
#     'open': 210.63,
#     'symbol': 'AAPL',
#     'timestamp': datetime.datetime(2025, 5, 15, 18, 52, tzinfo=TzInfo(UTC)),
#     'trade_count': 687.0,
#     'volume': 36844.0,
#     'vwap': 210.673863}, {   'close': 210.6298,
#     'high': 210.68,
#     'low': 210.53,
#     'open': 210.67,
#     'symbol': 'AAPL',
#     'timestamp': datetime.datetime(2025, 5, 15, 18, 53, tzinfo=TzInfo(UTC)),
#     'trade_count': 853.0,
#     'volume': 54936.0,
#     'vwap': 210.604393}, {   'close': 210.64,
#     'high': 210.6799,
#     'low': 210.535,
#     'open': 210.6,
#     'symbol': 'AAPL',
#     'timestamp': datetime.datetime(2025, 5, 15, 18, 54, tzinfo=TzInfo(UTC)),
#     'trade_count': 780.0,
#     'volume': 49291.0,
#     'vwap': 210.601543}, {   'close': 210.53,
#     'high': 210.63,
#     'low': 210.52,
#     'open': 210.63,
#     'symbol': 'AAPL',
#     'timestamp': datetime.datetime(2025, 5, 15, 18, 55, tzinfo=TzInfo(UTC)),
#     'trade_count': 743.0,
#     'volume': 39166.0,
#     'vwap': 210.567415}, {   'close': 210.54,
#     'high': 210.63,
#     'low': 210.49,
#     'open': 210.54,
#     'symbol': 'AAPL',
#     'timestamp': datetime.datetime(2025, 5, 15, 18, 56, tzinfo=TzInfo(UTC)),
#     'trade_count': 865.0,
#     'volume': 52109.0,
#     'vwap': 210.546305}, {   'close': 210.6692,
#     'high': 210.69,
#     'low': 210.51,
#     'open': 210.54,
#     'symbol': 'AAPL',
#     'timestamp': datetime.datetime(2025, 5, 15, 18, 57, tzinfo=TzInfo(UTC)),
#     'trade_count': 921.0,
#     'volume': 53130.0,
#     'vwap': 210.610254}, {   'close': 210.64,
#     'high': 210.7,
#     'low': 210.63,
#     'open': 210.675,
#     'symbol': 'AAPL',
#     'timestamp': datetime.datetime(2025, 5, 15, 18, 58, tzinfo=TzInfo(UTC)),
#     'trade_count': 795.0,
#     'volume': 54602.0,
#     'vwap': 210.656632}, {   'close': 210.65,
#     'high': 210.7,
#     'low': 210.58,
#     'open': 210.63,
#     'symbol': 'AAPL',
#     'timestamp': datetime.datetime(2025, 5, 15, 18, 59, tzinfo=TzInfo(UTC)),
#     'trade_count': 1011.0,
#     'volume': 68543.0,
#     'vwap': 210.645459}, {   'close': 210.72,
#     'high': 210.725,
#     'low': 210.59,
#     'open': 210.66,
#     'symbol': 'AAPL',
#     'timestamp': datetime.datetime(2025, 5, 15, 19, 0, tzinfo=TzInfo(UTC)),
#     'trade_count': 918.0,
#     'volume': 52503.0,
#     'vwap': 210.652968}, {   'close': 210.69,
#     'high': 210.7572,
#     'low': 210.67,
#     'open': 210.7,
#     'symbol': 'AAPL',
#     'timestamp': datetime.datetime(2025, 5, 15, 19, 1, tzinfo=TzInfo(UTC)),
#     'trade_count': 770.0,
#     'volume': 52078.0,
#     'vwap': 210.713706}, {   'close': 210.8,
#     'high': 210.8299,
#     'low': 210.65,
#     'open': 210.68,
#     'symbol': 'AAPL',
#     'timestamp': datetime.datetime(2025, 5, 15, 19, 2, tzinfo=TzInfo(UTC)),
#     'trade_count': 758.0,
#     'volume': 42600.0,
#     'vwap': 210.755006}, {   'close': 210.81,
#     'high': 210.84,
#     'low': 210.72,
#     'open': 210.79,
#     'symbol': 'AAPL',
#     'timestamp': datetime.datetime(2025, 5, 15, 19, 3, tzinfo=TzInfo(UTC)),
#     'trade_count': 712.0,
#     'volume': 43802.0,
#     'vwap': 210.786149}, {   'close': 210.9408,
#     'high': 210.9408,
#     'low': 210.81,
#     'open': 210.81,
#     'symbol': 'AAPL',
#     'timestamp': datetime.datetime(2025, 5, 15, 19, 4, tzinfo=TzInfo(UTC)),
#     'trade_count': 705.0,
#     'volume': 45171.0,
#     'vwap': 210.876557}, {   'close': 210.99,
#     'high': 210.99,
#     'low': 210.88,
#     'open': 210.93,
#     'symbol': 'AAPL',
#     'timestamp': datetime.datetime(2025, 5, 15, 19, 5, tzinfo=TzInfo(UTC)),
#     'trade_count': 878.0,
#     'volume': 64159.0,
#     'vwap': 210.93251}, {   'close': 210.99,
#     'high': 211.09,
#     'low': 210.95,
#     'open': 210.99,
#     'symbol': 'AAPL',
#     'timestamp': datetime.datetime(2025, 5, 15, 19, 6, tzinfo=TzInfo(UTC)),
#     'trade_count': 1414.0,
#     'volume': 110586.0,
#     'vwap': 211.022749}, {   'close': 210.8197,
#     'high': 211.03,
#     'low': 210.79,
#     'open': 210.99,
#     'symbol': 'AAPL',
#     'timestamp': datetime.datetime(2025, 5, 15, 19, 7, tzinfo=TzInfo(UTC)),
#     'trade_count': 1012.0,
#     'volume': 67282.0,
#     'vwap': 210.885805}, {   'close': 210.8095,
#     'high': 210.85,
#     'low': 210.63,
#     'open': 210.78,
#     'symbol': 'AAPL',
#     'timestamp': datetime.datetime(2025, 5, 15, 19, 8, tzinfo=TzInfo(UTC)),
#     'trade_count': 1272.0,
#     'volume': 82755.0,
#     'vwap': 210.734855}, {   'close': 210.665,
#     'high': 210.81,
#     'low': 210.66,
#     'open': 210.79,
#     'symbol': 'AAPL',
#     'timestamp': datetime.datetime(2025, 5, 15, 19, 9, tzinfo=TzInfo(UTC)),
#     'trade_count': 798.0,
#     'volume': 49966.0,
#     'vwap': 210.706313}, {   'close': 210.78,
#     'high': 210.84,
#     'low': 210.64,
#     'open': 210.65,
#     'symbol': 'AAPL',
#     'timestamp': datetime.datetime(2025, 5, 15, 19, 10, tzinfo=TzInfo(UTC)),
#     'trade_count': 1101.0,
#     'volume': 69196.0,
#     'vwap': 210.739199}, {   'close': 210.685,
#     'high': 210.801,
#     'low': 210.67,
#     'open': 210.77,
#     'symbol': 'AAPL',
#     'timestamp': datetime.datetime(2025, 5, 15, 19, 11, tzinfo=TzInfo(UTC)),
#     'trade_count': 875.0,
#     'volume': 54263.0,
#     'vwap': 210.754455}]}

# %%
class VWAPReversionStrategy(bt.Strategy):
    params = (
        ('vwap_dev_threshold', 0.002),  # 0.2%
        ('stop_loss', 0.01),             # 1%
        ('take_profit', 0.02),           # 2%
        ('max_hold_minutes', 10),        # optional time-based exit
    )

    def __init__(self):
        # Calculate VWAP indicator (Backtrader doesn’t have built-in VWAP, so define it)
        self.vwap = VWAP(self.data)
        self.entry_price = None
        self.order = None
        self.entry_bar = None

    def next(self):
        if self.order:
            return  # waiting for order to complete

        price = self.data.close[0]
        vwap_val = self.vwap[0]

        # Calculate deviation
        dev = abs(price - vwap_val) / vwap_val

        if not self.position:
            # Look for reversion signal: price crossed beyond threshold and back
            # For simplicity, assume: Enter long if price < VWAP*(1 - threshold)
            if price < vwap_val * (1 - self.params.vwap_dev_threshold):
                self.order = self.buy()
                self.entry_price = price
                self.entry_bar = len(self)

        else:
            # Manage open position with stop loss / take profit
            profit = (price - self.entry_price) / self.entry_price

            # Stop loss triggered?
            if profit <= -self.params.stop_loss:
                self.order = self.sell()
            # Take profit triggered?
            elif profit >= self.params.take_profit:
                self.order = self.sell()
            # Optional max hold time exit
            elif (len(self) - self.entry_bar) >= self.params.max_hold_minutes:
                self.order = self.sell()

# Custom VWAP indicator implementation needed
class VWAP(bt.Indicator):
    lines = ('vwap',)
    params = (('period', None),)

    def __init__(self):
        self.addminperiod(1)

    def next(self):
        # VWAP calculation: cumulative sum of (price * volume) / cumulative volume intraday
        # Backtrader handles 1 bar at a time, so need to keep track cumulatively per day
        if self.datas[0].datetime.date(0) != self.datas[0].datetime.date(-1):
            # New day, reset accumulators
            self.cum_vol = 0
            self.cum_vol_price = 0

        price = self.datas[0].close[0]
        vol = self.datas[0].volume[0]

        self.cum_vol += vol
        self.cum_vol_price += price * vol

        self.lines.vwap[0] = self.cum_vol_price / self.cum_vol if self.cum_vol > 0 else price

# %%
# Load your data into Backtrader feed (replace with your CSV path)
data = bt.feeds.GenericCSVData(
    dataname='your_intraday_data.csv',
    dtformat=('%Y-%m-%d %H:%M:%S'),
    timeframe=bt.TimeFrame.Minutes,
    compression=1,
    datetime=0,
    open=1,
    high=2,
    low=3,
    close=4,
    volume=5,
    openinterest=-1,
    headers=False,
)

# Parameter ranges to test
vwap_devs = [0.001, 0.002, 0.003]      # 0.1%, 0.2%, 0.3%
stop_losses = [0.005, 0.01, 0.015, 0.00]     # 0.5%, 1%, 1.5%
take_profits = [0.01, 0.02, 0.03]      # 1%, 2%, 3%

results = []

for vdev, sl, tp in itertools.product(vwap_devs, stop_losses, take_profits):
    cerebro = bt.Cerebro()
    cerebro.adddata(data)
    cerebro.addstrategy(VWAPReversionStrategy, 
                        vwap_dev_threshold=vdev, 
                        stop_loss=sl, 
                        take_profit=tp)
    cerebro.broker.setcash(500)  # your capital
    cerebro.broker.setcommission(commission=0.001)  # 0.1% commission per trade, adjust as needed

    result = cerebro.run()
    strat = result[0]

    # Collect performance metrics
    final_value = cerebro.broker.getvalue()
    pnl = final_value - 500
    results.append({
        'vwap_dev_threshold': vdev,
        'stop_loss': sl,
        'take_profit': tp,
        'final_value': final_value,
        'pnl': pnl,
        'total_trades': strat._trades_closed if hasattr(strat, '_trades_closed') else 'N/A',
        # You can add win rate, max drawdown, sharpe, etc. with more coding
    })

df_results = pd.DataFrame(results)
print(df_results)
df_results.to_csv('vwap_reversion_param_results.csv', index=False)
